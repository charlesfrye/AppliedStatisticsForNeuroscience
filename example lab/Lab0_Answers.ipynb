# %% [markdown]
# <img src="./img/HWNI_logo.svg"/>

# %% [markdown]
# # Lab 0 - Example

# %% [markdown]
# Each lab folder should have the following subfolders:
#
# - `img`, containing the logo image above and any other image data
# - `css`, containing the styling css for displaying the Pandas DataFrames (thanks Brandon Rhodes!)
# - `data`, containing all the data for the lab (usually `.csv` files)
# - `util`, containing any code that the students don't need to see, like boilerplate or plot-styling code.

# %%
#all imports and magics go at the top

#use this magic for inline plotting
# %matplotlib inline

# use the following style for cleaner plots
import matplotlib
matplotlib.style.use('ggplot')

#standard abbreviations
import numpy as np
import pandas as pd

#push helper functions to separate module
import util.plots as plot 

from IPython.core.display import HTML
css = open('./css/style-table.css').read() 
HTML('<style>{}</style>'.format(css)) #import css styling for tables; has to be last
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# </style>

# %% [markdown]
# ### Problem 1 - Loading Data

# %% [markdown]
# Data should be loaded in as a `pandas` data frame from a `.csv` file located in a subfolder called `data/`. Include a call to `head` if at all appropriate.

# %%
data = pd.read_csv('./data/2_1b.csv')

data.head()
# Out:
#    Saline_1  Parg  PargYomb  Saline_2
# 0      21.7  49.1       8.7       4.4
# 1      17.0  36.9      12.1      21.1
# 2      11.1  41.0       3.3      20.7
# 3       6.3  33.8      10.7      19.8
# 4      19.3  56.8      22.6      16.2

# %% [markdown]
# ### Problem 2 - Plotting Data

# %% [markdown]
# Using the `ggplot` style and adding thicker lines gets you relatively nice-looking plots.

# %%
experiment1 = data[['Saline_1','Parg']]

experiment1.plot(kind="hist",
                    linewidth=4,
                    alpha=0.6,
                    bins=20,
                    edgecolor='white');

# %% [markdown]
# So far as I can tell, there's not a `fill` option for the `kde` method, so we're stuck with just lines.

# %%
experiment1.plot(kind="kde",
                    linewidth=4,);

# %%
experiment2 = data[['Saline_2','PargYomb']]

experiment2.plot(kind="hist",
                    linewidth=4,
                    alpha=0.6,
                    bins=20,
                    edgecolor='white');

# %%
experiment2.plot(kind="kde",
                    linewidth=4);
